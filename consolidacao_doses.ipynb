# %%
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats
from scipy.stats import norm
import statsmodels.api as sm
import matplotlib.pyplot as plt
from scipy.stats import skew, norm
# %matplotlib inline

import warnings
warnings.filterwarnings(action="ignore")

# %%
df_origin = pd.read_csv('../data_volume/estado_df.csv', ';')
df_origin.head(3)
# Out:
#                                  document_id  \
# 0  69876967-a953-4ea9-ad4c-e77955ebb0d3-i0b0
# 1  d1985fbd-1a62-423f-8006-9d502ae25411-i0b0
# 2  7fe4757a-04b1-4ac1-8bc9-1c227632f430-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  d0186c353a471a7e6db313ab95099e718bacba728603a8...              41
# 1  7fec579b3c261e56a4c6394e1d36eb50054d6363d3eb4f...              47
# 2  de590f56bfff4d4c38de14ee02693a61bf547f2939b799...              42
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              1979-03-10                          F                        3
# 1              1973-05-20                          F                        1
# 2              1978-05-15                          F                        1
#
#   paciente_racaCor_valor  paciente_endereco_coIbgeMunicipio  \
# 0                  PARDA                           530010.0
# 1                 BRANCA                           530010.0
# 2                 BRANCA                           314810.0
#
#    paciente_endereco_coPais paciente_endereco_nmMunicipio  ...  \
# 0                      10.0                      BRASILIA  ...
# 1                      10.0                      BRASILIA  ...
# 2                      10.0                    PATROCINIO  ...
#
#     vacina_categoria_nome vacina_lote  vacina_fabricante_nome  \
# 0  Trabalhadores de Saúde      210013       FUNDACAO BUTANTAN
# 1  Trabalhadores de Saúde   202010036       FUNDACAO BUTANTAN
# 2  Trabalhadores de Saúde      210013       FUNDACAO BUTANTAN
#
#   vacina_fabricante_referencia      vacina_dataAplicacao  \
# 0  Organization/61189445000156  2021-02-22T03:00:00.000Z
# 1  Organization/61189445000156  2021-02-19T03:00:00.000Z
# 2  Organization/61189445000156  2021-02-25T03:00:00.000Z
#
#   vacina_descricao_dose vacina_codigo                          vacina_nome  \
# 0               2ª Dose            86  Covid-19-Coronavac-Sinovac/Butantan
# 1               2ª Dose            86  Covid-19-Coronavac-Sinovac/Butantan
# 2               2ª Dose            86  Covid-19-Coronavac-Sinovac/Butantan
#
#   sistema_origem data_importacao_rnds
# 0       Novo PNI  2021-02-23 12:24:47
# 1       Novo PNI  2021-03-22 16:34:46
# 2       Novo PNI  2021-02-28 11:51:55
#
# [3 rows x 33 columns]

# %%
df_origin.info()
columns = ['paciente_idade', 'paciente_enumSexoBiologico', 'paciente_racaCor_valor', 'paciente_endereco_coIbgeMunicipio',
           'estabelecimento_razaoSocial', 'vacina_grupoAtendimento_nome', 'vacina_categoria_nome', 'vacina_fabricante_nome',
           'vacina_dataAplicacao', 'vacina_descricao_dose', 'vacina_nome', 'sistema_origem']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213460 entries, 0 to 213459
# Data columns (total 33 columns):
# document_id                                 213460 non-null object
# paciente_id                                 213460 non-null object
# paciente_idade                              213460 non-null int64
# paciente_dataNascimento                     213460 non-null object
# paciente_enumSexoBiologico                  213460 non-null object
# paciente_racaCor_codigo                     213460 non-null int64
# paciente_racaCor_valor                      213460 non-null object
# paciente_endereco_coIbgeMunicipio           211505 non-null float64
# paciente_endereco_coPais                    211508 non-null float64
# paciente_endereco_nmMunicipio               211505 non-null object
# paciente_endereco_nmPais                    211508 non-null object
# paciente_endereco_uf                        211505 non-null object
# paciente_endereco_cep                       159021 non-null float64
# paciente_nacionalidade_enumNacionalidade    213190 non-null object
# estabelecimento_valor                       213460 non-null int64
# estabelecimento_razaoSocial                 213460 non-null object
# estalecimento_noFantasia                    213460 non-null object
# estabelecimento_municipio_codigo            213460 non-null int64
# estabelecimento_municipio_nome              213460 non-null object
# estabelecimento_uf                          213460 non-null object
# vacina_grupoAtendimento_codigo              213460 non-null int64
# vacina_grupoAtendimento_nome                213373 non-null object
# vacina_categoria_codigo                     213373 non-null float64
# vacina_categoria_nome                       213373 non-null object
# vacina_lote                                 213460 non-null object
# vacina_fabricante_nome                      213460 non-null object
# vacina_fabricante_referencia                213343 non-null object
# vacina_dataAplicacao                        213460 non-null object
# vacina_descricao_dose                       213460 non-null object
# vacina_codigo                               213460 non-null int64
# vacina_nome                                 213460 non-null object
# sistema_origem                              213460 non-null object
# data_importacao_rnds                        213460 non-null object
# dtypes: float64(4), int64(6), object(23)
# memory usage: 53.7+ MB

# %%
df = df_origin[columns]
df.head(3)
# Out:
#    paciente_idade paciente_enumSexoBiologico paciente_racaCor_valor  \
# 0              41                          F                  PARDA
# 1              47                          F                 BRANCA
# 2              42                          F                 BRANCA
#
#    paciente_endereco_coIbgeMunicipio  \
# 0                           530010.0
# 1                           530010.0
# 2                           314810.0
#
#                   estabelecimento_razaoSocial vacina_grupoAtendimento_nome  \
# 0      UNIDADE BASICA DE SAUDE N 17 CEILANDIA                       Outros
# 1  HOSPITAL MATERNO INFANTIL DE BRASILIA HMIB        Técnico de Enfermagem
# 2             HOSPITAL REGIONAL DE TAGUATINGA              Fisioterapeutas
#
#     vacina_categoria_nome vacina_fabricante_nome      vacina_dataAplicacao  \
# 0  Trabalhadores de Saúde      FUNDACAO BUTANTAN  2021-02-22T03:00:00.000Z
# 1  Trabalhadores de Saúde      FUNDACAO BUTANTAN  2021-02-19T03:00:00.000Z
# 2  Trabalhadores de Saúde      FUNDACAO BUTANTAN  2021-02-25T03:00:00.000Z
#
#   vacina_descricao_dose                          vacina_nome sistema_origem
# 0               2ª Dose  Covid-19-Coronavac-Sinovac/Butantan       Novo PNI
# 1               2ª Dose  Covid-19-Coronavac-Sinovac/Butantan       Novo PNI
# 2               2ª Dose  Covid-19-Coronavac-Sinovac/Butantan       Novo PNI

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213460 entries, 0 to 213459
# Data columns (total 12 columns):
# paciente_idade                       213460 non-null int64
# paciente_enumSexoBiologico           213460 non-null object
# paciente_racaCor_valor               213460 non-null object
# paciente_endereco_coIbgeMunicipio    211505 non-null float64
# estabelecimento_razaoSocial          213460 non-null object
# vacina_grupoAtendimento_nome         213373 non-null object
# vacina_categoria_nome                213373 non-null object
# vacina_fabricante_nome               213460 non-null object
# vacina_dataAplicacao                 213460 non-null object
# vacina_descricao_dose                213460 non-null object
# vacina_nome                          213460 non-null object
# sistema_origem                       213460 non-null object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 19.5+ MB

# %%
df_temp = df.groupby(['paciente_idade', 'vacina_descricao_dose'])['vacina_descricao_dose'].agg(['count']).sort_values(['paciente_idade']).rename_axis(["FaixaEtaria", "Dose"])
df_temp
# Out:
#                          count
# FaixaEtaria Dose
# 13              1ª Dose      1
# 15              1ª Dose      2
#                 2ª Dose      2
# 16              1ª Dose      3
#                 2ª Dose      1
# ...                        ...
# 111             1ª Dose      1
#                 2ª Dose      1
# 112             1ª Dose      1
# 121             1ª Dose      6
#                 2ª Dose      2
#
# [196 rows x 1 columns]

# %%
df_temp.reset_index()
# Out:
#      FaixaEtaria         Dose  count
# 0             13      1ª Dose      1
# 1             15      1ª Dose      2
# 2             15      2ª Dose      2
# 3             16      1ª Dose      3
# 4             16      2ª Dose      1
# ..           ...          ...    ...
# 191          111      1ª Dose      1
# 192          111      2ª Dose      1
# 193          112      1ª Dose      1
# 194          121      1ª Dose      6
# 195          121      2ª Dose      2
#
# [196 rows x 3 columns]

# %%
df_temp.to_csv('consolidacao_doses.csv')
